# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression

marks = pd.read_csv('marks.csv')
hours = pd.read_csv('hours.csv')



X = marks.values
y = hours.values



#presentation of data using matplotlib.pyplot 
# plt.scatter(X,Y)
# plt.xlabel("No of hours Studied")
# plt.ylabel("Marks")
# plt.show()

model = LinearRegression()

model.fit(X,y)

marks = 5
x_test = np.array(marks)
x_test = x_test.reshape(1,-1)

# model.predict(x_test)

X
# Out:
# array([[ 9.05],
#        [ 5.86],
#        [ 7.24],
#        [ 6.94],
#        [ 7.18],
#        [ 6.09],
#        [ 7.87],
#        [ 9.63],
#        [ 6.77],
#        [ 6.88],
#        [ 7.52],
#        [ 8.22],
#        [ 6.6 ],
#        [ 5.95],
#        [ 9.33],
#        [ 4.84],
#        [ 8.09],
#        [ 7.07],
#        [ 8.26],
#        [ 7.54],
#        [ 9.8 ],
#        [ 5.8 ],
#        [ 9.05],
#        [ 9.59],
#        [ 7.04],
#        [ 4.73],
#        [ 7.59],
#        [ 6.39],
#        [ 7.98],
#        [ 7.37],
#        [ 7.91],
#        [ 7.4 ],
#        [ 8.35],
#        [ 6.72],
#        [ 6.21],
#        [ 6.39],
#        [ 5.32],
#        [ 6.08],
#        [ 6.43],
#        [ 6.76],
#        [ 6.61],
#        [ 5.12],
#        [ 6.14],
#        [ 9.51],
#        [ 7.77],
#        [ 9.64],
#        [ 6.7 ],
#        [ 6.93],
#        [ 6.83],
#        [ 5.8 ],
#        [ 6.15],
#        [ 9.76],
#        [ 6.43],
#        [ 8.61],
#        [ 5.94],
#        [ 5.12],
#        [ 6.68],
#        [ 8.16],
#        [ 8.43],
#        [ 9.17],
#        [ 5.27],
#        [ 9.7 ],
#        [ 6.28],
#        [ 7.21],
#        [ 7.62],
#        [ 6.17],
#        [ 5.09],
#        [ 6.51],
#        [ 7.13],
#        [ 6.09],
#        [ 6.07],
#        [ 7.41],
#        [ 6.88],
#        [ 7.54],
#        [ 6.97],
#        [ 6.08],
#        [ 8.65],
#        [ 7.95],
#        [ 8.32],
#        [ 5.6 ],
#        [ 8.24],
#        [ 5.35],
#        [ 6.46],
#        [ 5.64],
#        [ 4.92],
#        [ 9.39],
#        [ 6.33],
#        [ 6.72],
#        [ 6.61],
#        [ 7.48],
#        [ 9.07],
#        [ 9.18],
#        [ 5.81],
#        [ 5.65],
#        [ 5.51],
#        [ 5.75],
#        [ 9.6 ],
#        [ 7.04],
#        [ 6.14],
#        [ 6.39],
#        [11.8 ],
#        [10.3 ],
#        [ 8.94],
#        [ 8.17],
#        [ 7.98],
#        [14.4 ],
#        [11.5 ],
#        [14.3 ],
#        [ 8.74],
#        [ 8.87]])
